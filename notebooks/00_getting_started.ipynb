# %% [markdown]
# # AI Learning — Getting Started
#
# This notebook verifies the environment and demonstrates the core libraries available in this project.
#
# **Kernel:** `Python (AI Learning)` — select it from *Kernel → Change kernel* if not already active.

# %% [markdown]
# ## 1. Environment Check

# %%
import sys
print(f"Python: {sys.version}")
print(f"Executable: {sys.executable}")
# Out:
# Python: 3.14.4 (main, Apr 14 2026, 14:46:33) [Clang 22.1.3 ]
# Executable: /Users/I353174/X01/AI/.venv/bin/python

# %%
# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

print(f"NumPy   : {np.__version__}")
print(f"Pandas  : {pd.__version__}")
print(f"PyTorch : {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# NumPy   : 2.5.3
# Pandas  : 3.0.5
# PyTorch : 2.14.0
# CUDA available: False

# %%
# HuggingFace ecosystem
import transformers, datasets, tokenizers, peft, accelerate, evaluate
print(f"Transformers : {transformers.__version__}")
print(f"Datasets     : {datasets.__version__}")
print(f"PEFT         : {peft.__version__}")
# Out:
# Transformers : 5.17.0
# Datasets     : 5.0.1
# PEFT         : 0.21.0

# %%
# LangChain / LangGraph
import langchain_core, langgraph
from importlib.metadata import version
print(f"LangChain-core : {langchain_core.__version__}")
print(f"LangGraph      : {version('langgraph')}")
# Out:
# LangChain-core : 1.6.3
# LangGraph      : 1.2.11

# %%
# Load .env (GEMINI_API_KEY etc.)
from dotenv import load_dotenv
import os

load_dotenv()  # reads ../.env relative to the notebook
key = os.getenv("GEMINI_API_KEY")
print(f"GEMINI_API_KEY loaded: {'yes ✓' if key else 'no — add it to .env'}")
# Out:
# GEMINI_API_KEY loaded: yes ✓

# %% [markdown]
# ## 2. Quick NumPy & Matplotlib Smoke Test

# %%
x = np.linspace(0, 2 * np.pi, 200)
plt.figure(figsize=(7, 3))
plt.plot(x, np.sin(x), label="sin(x)")
plt.plot(x, np.cos(x), label="cos(x)")
plt.legend()
plt.title("Sine & Cosine")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Quick PyTorch Smoke Test

# %%
# Simple linear layer forward pass
import torch.nn as nn

layer = nn.Linear(4, 2)
x = torch.randn(3, 4)   # batch of 3, 4 features
out = layer(x)
print(f"Input shape : {x.shape}")
print(f"Output shape: {out.shape}")
print(f"Output:\n{out.detach()}")
# Out:
# Input shape : torch.Size([3, 4])
# Output shape: torch.Size([3, 2])
# Output:
# tensor([[-0.0973, -0.1150],
#         [-1.8782, -0.2518],
#         [ 0.2679,  0.3367]])

# %% [markdown]
# ---
# All checks passed — environment is ready. Create new notebooks in this `notebooks/` folder and select the **Python (AI Learning)** kernel.
